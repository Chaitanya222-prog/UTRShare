# %%
#auth.authenticate_user()
from gspread_dataframe import set_with_dataframe
#from geopy.geocoders import Nominatim
#from geopy import distance
import gspread
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import seaborn as sns
#sns.set()
#from sklearn.cluster import KMeans
from datetime import datetime, timedelta
#from oauth2client.client import GoogleCredentials

from google.oauth2.service_account import Credentials

#gc = gspread.service_account(filename="/content/creds.json")
import smtplib
from smtplib import SMTPException
from email.message import EmailMessage
from datetime import date
from datetime import datetime, timedelta
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.base import MIMEBase
from email import encoders
from email.message import EmailMessage
from tabulate import tabulate

# %%
scopes = [
    'https://www.googleapis.com/auth/spreadsheets',
    'https://www.googleapis.com/auth/drive'
]
credentials = Credentials.from_service_account_file(
    '/content/secret_key.json',
    scopes=scopes
)
gc = gspread.authorize(credentials)

# %%
NEFT_Data = pd.DataFrame.from_records(gc.open('UTR_Mail_Push').worksheet('NEFT_Final').get_all_records())
FE_Data = pd.DataFrame.from_records(gc.open('UTR_Mail_Push').worksheet('FE_Final').get_all_records())

# %%
print(NEFT_Data)
# Out:
#             Name     Transaction Date  \
# 0         Bhopal  25/01/2024 05:01:20
# 1     Samastipur  25/01/2024 05:01:20
# 2    Muzaffarpur  25/01/2024 05:01:20
# 3          Hapur  25/01/2024 05:01:33
# 4        Katihar  25/01/2024 05:01:34
# 5    Muzaffarpur  25/01/2024 05:01:34
# 6      Darbhanga  25/01/2024 05:01:34
# 7       Bahraich  25/01/2024 05:01:34
# 8    VaranasiClu  25/01/2024 05:01:34
# 9          Hapur  25/01/2024 05:01:41
# 10       Sasaram  25/01/2024 05:01:41
# 11      Motihari  25/01/2024 05:01:41
# 12       Sasaram  25/01/2024 05:01:41
# 13    Samastipur  25/01/2024 05:02:56
# 14       Bettiah  25/01/2024 05:03:05
# 15           FnV  25/01/2024 14:32:35
# 16     AkolaClus  25/01/2024 14:32:35
# 17      Motihari  25/01/2024 14:32:35
# 18      Ghazipur  25/01/2024 14:32:35
# 19      Ghazipur  25/01/2024 14:32:36
# 20      Ghazipur  25/01/2024 14:32:36
# 21  VaranasiClus  25/01/2024 14:32:36
# 22    PatnaClust  25/01/2024 17:13:40
# ...

# %%
#NEFT_Data['Name'] = NEFT_Data['Name'].str.lower()
#print(NEFT_Data)

# %%
#HeadOffice

HeadOffice_NEFT = NEFT_Data.query('Name.str.startswith("Head")', engine='python')
df1 = HeadOffice_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
HeadOffice_NEFT = FE_Data.query('Name.str.startswith("Head")', engine='python')
df2 = HeadOffice_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Patna_NEFT = NEFT_Data.query('Name.str.startswith("Patn")', engine='python')
df4 = Patna_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Patna_NEFT = FE_Data.query('Name.str.startswith("Patn")', engine='python')
df5 = Patna_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2,df4,df5]
HeadOffice_Raw = pd.concat(df3)
Raw_Data = HeadOffice_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'anish.kumar@agrevolution.in'
cc = 'avinash.kumar@agrevolution.in'
file_name = 'HeadOffice.csv'


msg = EmailMessage()
msg['Subject'] = 'Head Office || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Anish Kumar,\nPlease find below attachment of UTR of Head Office.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Begusarai

Begusarai_NEFT = NEFT_Data.query('Name.str.startswith("Begu")', engine='python')
df1 = Begusarai_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Begusarai_NEFT = FE_Data.query('Name.str.startswith("Begu")', engine='python')
df2 = Begusarai_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Begusarai_Raw = pd.concat(df3)
Raw_Data = Begusarai_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'mukeshk.nagar@agrevolution.in'
cc = 'Anup.sinha@agrevolution.in'
file_name = 'Begusarai.csv'


msg = EmailMessage()
msg['Subject'] = 'Begusarai || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Aditya Thakur,\nPlease find below attachment of UTR of Begusarai.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Nawada

Nawada_NEFT = NEFT_Data.query('Name.str.startswith("Nawa")', engine='python')
df1 = Nawada_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Nawada_NEFT = FE_Data.query('Name.str.startswith("Nawa")', engine='python')
df2 = Nawada_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Nawada_Raw = pd.concat(df3)
Raw_Data = Nawada_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'ritesh.raj1@agrevolution.in'
cc = 'Anup.sinha@agrevolution.in'
file_name = 'Nawada.csv'


msg = EmailMessage()
msg['Subject'] = 'Nawada || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Ritesh Raj,\nPlease find below attachment of UTR of Nawada.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Saharsa

Saharsa_NEFT = NEFT_Data.query('Name.str.startswith("Saha")', engine='python')
df1 = Saharsa_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Saharsa_NEFT = FE_Data.query('Name.str.startswith("Saha")', engine='python')
df2 = Saharsa_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Saharsa_Raw = pd.concat(df3)
Raw_Data = Saharsa_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'mrinal.thakur@agrevolution.in'
cc = 'sunit.suman@agrevolution.in'
file_name = 'Saharsa.csv'


msg = EmailMessage()
msg['Subject'] = 'Saharsa || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Mrinal Thakur,\nPlease find below attachment of UTR of Saharsa.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Katihar

Katihar_NEFT = NEFT_Data.query('Name.str.startswith("Kati")', engine='python')
df1 = Katihar_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Katihar_NEFT = FE_Data.query('Name.str.startswith("Kati")', engine='python')
df2 = Katihar_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Katihar_Raw = pd.concat(df3)
Raw_Data = Katihar_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'pradeepk.paul@agrevolution.in'
cc = 'sunit.suman@agrevolution.in'
file_name = 'Katihar.csv'


msg = EmailMessage()
msg['Subject'] = 'Katihar || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Pradeep Paul,\nPlease find below attachment of UTR of Katihar.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Lakhisarai

Lakhisarai_NEFT = NEFT_Data.query('Name.str.startswith("Lakh")', engine='python')
df1 = Lakhisarai_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Lakhisarai_NEFT = FE_Data.query('Name.str.startswith("Lakh")', engine='python')
df2 = Lakhisarai_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Lakhisarai_Raw = pd.concat(df3)
Raw_Data = Lakhisarai_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'santosh.sharma@agrevolution.in'
cc = 'Anup.sinha@agrevolution.in'
file_name = 'Lakhisarai.csv'


msg = EmailMessage()
msg['Subject'] = 'Lakhisarai || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Santosh Sharma,\nPlease find below attachment of UTR of Lakhisarai.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Arrah

Arrah_NEFT = NEFT_Data.query('Name.str.startswith("Arra")', engine='python')
df1 = Arrah_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Arrah_NEFT = FE_Data.query('Name.str.startswith("Arra")', engine='python')
df2 = Arrah_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Arrah_Raw = pd.concat(df3)
Raw_Data = Arrah_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'kundan.gupta@agrevolution.in'
cc = 'avinash.kumar@agrevolution.in'
file_name = 'Arrah.csv'


msg = EmailMessage()
msg['Subject'] = 'Arrah || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Kundan Kumar Gupta,\nPlease find below attachment of UTR of Arrah.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Bettiah

Bettiah_NEFT = NEFT_Data.query('Name.str.startswith("Bett")', engine='python')
df1 = Bettiah_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Bettiah_NEFT = FE_Data.query('Name.str.startswith("Bett")', engine='python')
df2 = Bettiah_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Bettiah_Raw = pd.concat(df3)
Raw_Data = Bettiah_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'shatrughan.kumar@agrevolution.in'
cc = 'rajeev.kumar3@agrevolution.in'
file_name = 'Bettiah.csv'


msg = EmailMessage()
msg['Subject'] = 'Bettiah || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi shatrughan kumar,\nPlease find below attachment of UTR of Bettiah.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Darbhanga

Darbhanga_NEFT = NEFT_Data.query('Name.str.startswith("Darb")', engine='python')
df1 = Darbhanga_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Darbhanga_NEFT = FE_Data.query('Name.str.startswith("Darb")', engine='python')
df2 = Darbhanga_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Darbhanga_Raw = pd.concat(df3)
Raw_Data = Darbhanga_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'pappu.kumar2@agrevolution.in'
cc = 'rajeev.kumar3@agrevolution.in'
file_name = 'Darbhanga.csv'


msg = EmailMessage()
msg['Subject'] = 'Darbhanga || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Pappu Kumar,\nPlease find below attachment of UTR of Darbhanga.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#BiharSharif

BiharSharif_NEFT = NEFT_Data.query('Name.str.startswith("Biha")', engine='python')
df1 = BiharSharif_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
BiharSharif_NEFT = FE_Data.query('Name.str.startswith("Biha")', engine='python')
df2 = BiharSharif_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
BiharSharif_Raw = pd.concat(df3)
Raw_Data = BiharSharif_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'divesh.kumar@agrevolution.in'
cc = 'Anup.sinha@agrevolution.in'
file_name = 'BiharSharif.csv'


msg = EmailMessage()
msg['Subject'] = 'Bihar Sharif || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Divesh Kumar,\nPlease find below attachment of UTR of Bihar Sharif.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Samastipur

Samastipur_NEFT = NEFT_Data.query('Name.str.startswith("Sama")', engine='python')
df1 = Samastipur_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Samastipur_NEFT = FE_Data.query('Name.str.startswith("Sama")', engine='python')
df2 = Samastipur_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Samastipur_Raw = pd.concat(df3)
Raw_Data = Samastipur_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'rakesh.ranjan1@agrevolution.in'
cc = 'rajeev.kumar3@agrevolution.in'
file_name = 'Samastipur.csv'


msg = EmailMessage()
msg['Subject'] = 'Samastipur || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Rakesh Ranjan,\nPlease find below attachment of UTR of Samastipur.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Purnea

Purnea_NEFT = NEFT_Data.query('Name.str.startswith("Purn")', engine='python')
df1 = Purnea_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Purnea_NEFT = FE_Data.query('Name.str.startswith("Purn")', engine='python')
df2 = Purnea_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Purnea_Raw = pd.concat(df3)
Raw_Data = Purnea_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'deepak.jha@agrevolution.in'
cc = 'sunit.suman@agrevolution.in'
file_name = 'Purnea.csv'


msg = EmailMessage()
msg['Subject'] = 'Purnea || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Deepak Kumar Jha,\nPlease find below attachment of UTR of Purnea.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Vaishali

Vaishali_NEFT = NEFT_Data.query('Name.str.startswith("Vais")', engine='python')
df1 = Vaishali_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Vaishali_NEFT = FE_Data.query('Name.str.startswith("Vais")', engine='python')
df2 = Vaishali_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Vaishali_Raw = pd.concat(df3)
Raw_Data = Vaishali_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'prashuram.kumar@agrevolution.in'
cc = 'rajeev.kumar3@agrevolution.in'
file_name = 'Vaishali.csv'


msg = EmailMessage()
msg['Subject'] = 'Vaishali || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Prashuram Kumar,\nPlease find below attachment of UTR of Vaishali.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Muzaffarpur

Muzaffarpr_NEFT = NEFT_Data.query('Name.str.startswith("Muza")', engine='python')
df1 = Muzaffarpr_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Muzaffarpr_NEFT = FE_Data.query('Name.str.startswith("Muza")', engine='python')
df2 = Muzaffarpr_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Muzaffarpr_Raw = pd.concat(df3)
Raw_Data = Muzaffarpr_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'rupesh.singh@agrevolution.in'
cc = 'rajeev.kumar3@agrevolution.in'
file_name = 'Muzaffarpur.csv'


msg = EmailMessage()
msg['Subject'] = 'Muzaffarpur || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Rupesh Singh,\nPlease find below attachment of UTR of Muzaffarpur.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Mohania

Mohania_NEFT = NEFT_Data.query('Name.str.startswith("Moha")', engine='python')
df1 = Mohania_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Mohania_NEFT = FE_Data.query('Name.str.startswith("Moha")', engine='python')
df2 = Mohania_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Mohania_Raw = pd.concat(df3)
Raw_Data = Mohania_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'aditya.thakur@agrevolution.in'
cc = 'avinash.kumar@agrevolution.in'
file_name = 'Mohania.csv'


msg = EmailMessage()
msg['Subject'] = 'Mohania || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Mukesh Nagar,\nPlease find below attachment of UTR of Mohania.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Motihari

Motihari_NEFT = NEFT_Data.query('Name.str.startswith("Moti")', engine='python')
df1 = Motihari_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Motihari_NEFT = FE_Data.query('Name.str.startswith("Moti")', engine='python')
df2 = Motihari_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Motihari_Raw = pd.concat(df3)
Raw_Data = Motihari_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'ritu.raj@agrevolution.in'
cc = 'rajeev.kumar3@agrevolution.in'
file_name = 'Motihari.csv'


msg = EmailMessage()
msg['Subject'] = 'Motihari || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Ritu Raj,\nPlease find below attachment of UTR of Motihari.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Sitamarhi

Sitamarhi_NEFT = NEFT_Data.query('Name.str.startswith("Sitam")', engine='python')
df1 = Sitamarhi_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Sitamarhi_NEFT = FE_Data.query('Name.str.startswith("Sitam")', engine='python')
df2 = Sitamarhi_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Sitamarhi_Raw = pd.concat(df3)
Raw_Data = Sitamarhi_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'dilip.prajapati1@agrevolution.in'
cc = 'rajeev.kumar3@agrevolution.in'
file_name = 'Sitamarhi.csv'


msg = EmailMessage()
msg['Subject'] = 'Sitamarhi || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Dilip Prajapati,\nPlease find below attachment of UTR of Sitamarhi.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Dhamtari

Dhamtari_NEFT = NEFT_Data.query('Name.str.startswith("Dham")', engine='python')
df1 = Dhamtari_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Dhamtari_NEFT = FE_Data.query('Name.str.startswith("Dham")', engine='python')
df2 = Dhamtari_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Dhamtari_Raw = pd.concat(df3)
Raw_Data = Dhamtari_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'yuvraj.bais@agrevolution.in'
cc = 'mahesh.kumar2@agrevolution.in'
file_name = 'Dhamtari.csv'


msg = EmailMessage()
msg['Subject'] = 'Dhamtari || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Yuvraj Bais,\nPlease find below attachment of UTR of Dhamtari.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Raipur

Raipur_NEFT = NEFT_Data.query('Name.str.startswith("Raip")', engine='python')
df1 = Raipur_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Raipur_NEFT = FE_Data.query('Name.str.startswith("Raip")', engine='python')
df2 = Raipur_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Raipur_Raw = pd.concat(df3)
Raw_Data = Raipur_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'manoj.tandi@agrevolution.in'
cc = 'mahesh.kumar2@agrevolution.in'
file_name = 'Raipur.csv'


msg = EmailMessage()
msg['Subject'] = 'Raipur || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Manoj Tandi,\nPlease find below attachment of UTR of Raipur.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Ambikapur

Ambikapur_NEFT = NEFT_Data.query('Name.str.startswith("Ambi")', engine='python')
df1 = Ambikapur_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Ambikapur_NEFT = FE_Data.query('Name.str.startswith("Ambi")', engine='python')
df2 = Ambikapur_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Ambikapur_Raw = pd.concat(df3)
Raw_Data = Ambikapur_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'yogesh.singh@agrevolution.in'
cc = 'mahesh.kumar2@agrevolution.in'
file_name = 'Ambikapur.csv'


msg = EmailMessage()
msg['Subject'] = 'Ambikapur || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Vaibhav Kashyap,\nPlease find below attachment of UTR of Ambikapur.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Bilaspur

Bilaspur_NEFT = NEFT_Data.query('Name.str.startswith("Bila")', engine='python')
df1 = Bilaspur_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Bilaspur_NEFT = FE_Data.query('Name.str.startswith("Bila")', engine='python')
df2 = Bilaspur_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Bilaspur_Raw = pd.concat(df3)
Raw_Data = Bilaspur_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'sheo.kumar@agrevolution.in'
cc = 'mahesh.kumar2@agrevolution.in'
file_name = 'Bilaspur.csv'


msg = EmailMessage()
msg['Subject'] = 'Bilaspur || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Sheo Kumar,\nPlease find below attachment of UTR of Bilaspur.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Nagaur

Nagaur_NEFT = NEFT_Data.query('Name.str.startswith("Naga")', engine='python')
df1 = Nagaur_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Bilaspur_NEFT = FE_Data.query('Name.str.startswith("Naga")', engine='python')
df2 = Nagaur_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Nagaur_Raw = pd.concat(df3)
Raw_Data = Nagaur_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'Prince.pareek@agrevolution.in'
cc = 'vikash.mishra@agrevolution.in'
file_name = 'Nagaur.csv'


msg = EmailMessage()
msg['Subject'] = 'Nagaur || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Prince Pareek,\nPlease find below attachment of UTR of Nagaur.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Sri Ganganagar

SriGanganagar_NEFT = NEFT_Data.query('Name.str.startswith("Sri")', engine='python')
df1 = SriGanganagar_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
SriGanganagar_NEFT = FE_Data.query('Name.str.startswith("Sri")', engine='python')
df2 = SriGanganagar_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
SriGanganagar_Raw = pd.concat(df3)
Raw_Data = SriGanganagar_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'sushil.soni@agrevolution.in'
cc = 'vikash.mishra@agrevolution.in'
file_name = 'Nagaur.csv'


msg = EmailMessage()
msg['Subject'] = 'Sri Ganganagar || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Sushil Soni,\nPlease find below attachment of UTR of Sri Ganganagar.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)
