# %%
#auth.authenticate_user()
from gspread_dataframe import set_with_dataframe
#from geopy.geocoders import Nominatim
#from geopy import distance
import gspread
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import seaborn as sns
#sns.set()
#from sklearn.cluster import KMeans
from datetime import datetime, timedelta
#from oauth2client.client import GoogleCredentials

from google.oauth2.service_account import Credentials

#gc = gspread.service_account(filename="/content/creds.json")
import smtplib
from smtplib import SMTPException
from email.message import EmailMessage
from datetime import date
from datetime import datetime, timedelta
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.base import MIMEBase
from email import encoders
from email.message import EmailMessage
from tabulate import tabulate
import time

# %%
scopes = [
    'https://www.googleapis.com/auth/spreadsheets',
    'https://www.googleapis.com/auth/drive'
]
credentials = Credentials.from_service_account_file(
    '/content/secret_key.json',
    scopes=scopes
)
gc = gspread.authorize(credentials)

# %%
NEFT_Data = pd.DataFrame.from_records(gc.open('UTR_Mail_Push').worksheet('NEFT_Final').get_all_records())
FE_Data = pd.DataFrame.from_records(gc.open('UTR_Mail_Push').worksheet('FE_Final').get_all_records())

# %%
print(NEFT_Data)
# Out:
#             Name     Transaction Date  \
# 0       Shajapur  29/01/2024 14:02:34
# 1          Arrah  29/01/2024 14:02:34
# 2          Arrah  29/01/2024 14:02:34
# 3    Biharsharif  29/01/2024 14:02:34
# 4       Motihari  29/01/2024 14:02:34
# 5       Motihari  29/01/2024 14:02:34
# 6       Motihari  29/01/2024 14:02:34
# 7     HeadOffice  29/01/2024 14:02:34
# 8    PatnaCluste  29/01/2024 14:02:34
# 9    Biharsharif  29/01/2024 14:02:34
# 10  PatnaCluster  29/01/2024 14:02:34
# 11    PatnaClust  29/01/2024 14:02:34
# 12    PatnaClust  29/01/2024 14:02:34
# 13    PatnaClust  29/01/2024 14:02:34
# 14    PatnaClust  29/01/2024 14:02:34
# 15       Bettiah  29/01/2024 14:02:34
# 16      Motihari  29/01/2024 14:02:35
# 17        Bhopal  29/01/2024 14:02:35
# 18        Ballia  29/01/2024 17:08:54
# 19        Ballia  29/01/2024 17:08:54
# 20     Begusarai  29/01/2024 17:08:54
# 21     Begusarai  29/01/2024 17:08:54
# 22     Begusarai  29/01/2024 17:08:54
# ...

# %%
#NEFT_Data['Name'] = NEFT_Data['Name'].str.lower()
#print(NEFT_Data)

# %%
#Arariya

Arariya_NEFT = NEFT_Data.query('Name.str.startswith("Arar")', engine='python')
df1 = Arariya_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Arariya_NEFT = FE_Data.query('Name.str.startswith("Arar")', engine='python')
df2 = Arariya_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Arariya_Raw = pd.concat(df3)
Raw_Data = Arariya_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'ashtam.singh@agrevolution.in'
cc = 'sunit.suman@agrevolution.in'
file_name = 'Arariya.csv'


msg = EmailMessage()
msg['Subject'] = 'Arariya || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Ashtam Kumar Singh,\nPlease find below attachment of UTR of Arariya.\n\n\n\nRegards\nAmit Yadav')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Bhagalpur

Bhagalpur_NEFT = NEFT_Data.query('Name.str.startswith("Bhag")', engine='python')
df1 = Bhagalpur_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Bhagalpur_NEFT = FE_Data.query('Name.str.startswith("Bhag")', engine='python')
df2 = Bhagalpur_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Bhagalpur_Raw = pd.concat(df3)
Raw_Data = Bhagalpur_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'deepak.jha@agrevolution.in'
cc = 'sunit.suman@agrevolution.in'
file_name = 'Bhagalpur.csv'


msg = EmailMessage()
msg['Subject'] = 'Bhagalpur || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Deepak Kumar Jha,\nPlease find below attachment of UTR of Bhagalpur.\n\n\n\nRegards\nAmit Yadav')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Khagaria

Khagaria_NEFT = NEFT_Data.query('Name.str.startswith("Khag")', engine='python')
df1 = Khagaria_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Khagaria_NEFT = FE_Data.query('Name.str.startswith("Khag")', engine='python')
df2 = Khagaria_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Khagaria_Raw = pd.concat(df3)
Raw_Data = Khagaria_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'dharamveer.kumar@agrevolution.in'
cc = 'Anup.sinha@agrevolution.in'
file_name = 'Khagaria.csv'


msg = EmailMessage()
msg['Subject'] = 'Khagaria || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Dharamveer kumar,\nPlease find below attachment of UTR of Khagaria.\n\n\n\nRegards\nAmit Yadav')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Madhepura

Madhepura_NEFT = NEFT_Data.query('Name.str.startswith("Madh")', engine='python')
df1 = Madhepura_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Madhepura_NEFT = FE_Data.query('Name.str.startswith("Madh")', engine='python')
df2 = Madhepura_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Madhepura_Raw = pd.concat(df3)
Raw_Data = Madhepura_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'nandan.kumar1@agrevolution.in'
cc = 'sunit.suman@agrevolution.in'
file_name = 'Madhepura.csv'


msg = EmailMessage()
msg['Subject'] = 'Madhepura || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Nandan Jha,\nPlease find below attachment of UTR of Madhepura.\n\n\n\nRegards\nAmit Yadav')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Saran

Saran_NEFT = NEFT_Data.query('Name.str.startswith("Sara")', engine='python')
df1 = Saran_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Saran_NEFT = FE_Data.query('Name.str.startswith("Sara")', engine='python')
df2 = Saran_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Saran_Raw = pd.concat(df3)
Raw_Data = Saran_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'dharamvir.ojha@agrevolution.in'
cc = 'avinash.kumar@agrevolution.in'
file_name = 'Saran.csv'


msg = EmailMessage()
msg['Subject'] = 'Saran || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Dharamvir Ojha,\nPlease find below attachment of UTR of Saran.\n\n\n\nRegards\nAmit Yadav')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Sasaram

Sasaram_NEFT = NEFT_Data.query('Name.str.startswith("Sasa")', engine='python')
df1 = Sasaram_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Sasaram_NEFT = FE_Data.query('Name.str.startswith("Sasa")', engine='python')
df2 = Sasaram_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Sasaram_Raw = pd.concat(df3)
Raw_Data = Sasaram_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'praveen.kumar@agrevolution.in'
cc = 'avinash.kumar@agrevolution.in'
file_name = 'Sasaram.csv'


msg = EmailMessage()
msg['Subject'] = 'Sasaram || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Praveen Kumar,\nPlease find below attachment of UTR of Sasaram.\n\n\n\nRegards\nAmit Yadav')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Siwan

Siwan_NEFT = NEFT_Data.query('Name.str.startswith("Siwa")', engine='python')
df1 = Siwan_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Siwan_NEFT = FE_Data.query('Name.str.startswith("Siwa")', engine='python')
df2 = Siwan_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Siwan_Raw = pd.concat(df3)
Raw_Data = Siwan_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'Hridyanand@agrevolution.in'
cc = 'avinash.kumar@agrevolution.in'
file_name = 'Siwan.csv'


msg = EmailMessage()
msg['Subject'] = 'Siwan || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Hridya Nand Pandey,\nPlease find below attachment of UTR of Siwan.\n\n\n\nRegards\nAmit Yadav')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Hazaribagh

Hazaribagh_NEFT = NEFT_Data.query('Name.str.startswith("Haza")', engine='python')
df1 = Hazaribagh_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Hazaribagh_NEFT = FE_Data.query('Name.str.startswith("Haza")', engine='python')
df2 = Hazaribagh_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Hazaribagh_Raw = pd.concat(df3)
Raw_Data = Hazaribagh_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'neeraj.prakash@agrevolution.in'
cc = 'vishal.pandey@agrevolution.in'
file_name = 'Hazaribagh.csv'


msg = EmailMessage()
msg['Subject'] = 'Hazaribagh || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Sachin Kumar,\nPlease find below attachment of UTR of Hazaribagh.\n\n\n\nRegards\nAmit Yadav')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Ranchi

Ranchi_NEFT = NEFT_Data.query('Name.str.startswith("Ranc")', engine='python')
df1 = Ranchi_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Ranchi_NEFT = FE_Data.query('Name.str.startswith("Ranc")', engine='python')
df2 = Ranchi_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Ranchi_Raw = pd.concat(df3)
Raw_Data = Ranchi_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'sanu.bhattacharya@agrevolution.in'
cc = 'vishal.pandey@agrevolution.in'
file_name = 'Ranchi.csv'


msg = EmailMessage()
msg['Subject'] = 'Ranchi || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Sanu Bhattacharya,\nPlease find below attachment of UTR of Ranchi.\n\n\n\nRegards\nAmit Yadav')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Giridih

Giridih_NEFT = NEFT_Data.query('Name.str.startswith("Giri")', engine='python')
df1 = Giridih_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Giridih_NEFT = FE_Data.query('Name.str.startswith("Giri")', engine='python')
df2 = Giridih_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Giridih_Raw = pd.concat(df3)
Raw_Data = Giridih_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'amit.hindustani@agrevolution.in'
cc = 'vishal.pandey@agrevolution.in'
file_name = 'Giridih.csv'


msg = EmailMessage()
msg['Subject'] = 'Samastipur || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Amit Hindustani,\nPlease find below attachment of UTR of Giridih.\n\n\n\nRegards\nAmit Yadav')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Bhadrak

Bhadrak_NEFT = NEFT_Data.query('Name.str.startswith("Bhad")', engine='python')
df1 = Bhadrak_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Bhadrak_NEFT = FE_Data.query('Name.str.startswith("Bhad")', engine='python')
df2 = Bhadrak_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Bhadrak_Raw = pd.concat(df3)
Raw_Data = Bhadrak_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'susanta.sahoo@agrevolution.in'
cc = 'pratyushak.pradhan@agrevolution.in'
file_name = 'Bhadrak.csv'


msg = EmailMessage()
msg['Subject'] = 'Bhadrak || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Susanta Kumar Sahoo,\nPlease find below attachment of UTR of Bhadrak.\n\n\n\nRegards\nAmit Yadav')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Bhawanipatna

Bhawanipatna_NEFT = NEFT_Data.query('Name.str.startswith("Bhaw")', engine='python')
df1 = Bhawanipatna_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Bhawanipatna_NEFT = FE_Data.query('Name.str.startswith("Bhaw")', engine='python')
df2 = Bhawanipatna_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Bhawanipatna_Raw = pd.concat(df3)
Raw_Data = Bhawanipatna_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'saubhagya.mohapatra@agrevolution.in'
cc = 'pratyushak.pradhan@agrevolution.in'
file_name = 'Bhawanipatna.csv'


msg = EmailMessage()
msg['Subject'] = 'Bhawanipatna || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Saubhagya Mohapatra,\nPlease find below attachment of UTR of Bhawanipatna.\n\n\n\nRegards\nAmit Yadav')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Cuttack

Cuttack_NEFT = NEFT_Data.query('Name.str.startswith("Cutt")', engine='python')
df1 = Cuttack_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Cuttack_NEFT = FE_Data.query('Name.str.startswith("Cutt")', engine='python')
df2 = Cuttack_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Cuttack_Raw = pd.concat(df3)
Raw_Data = Cuttack_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'lagen.nayak@agrevolution.in'
cc = 'pratyushak.pradhan@agrevolution.in'
file_name = 'Cuttack.csv'


msg = EmailMessage()
msg['Subject'] = 'Cuttack || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Lagen Kumar Nayak,\nPlease find below attachment of UTR of Cuttack.\n\n\n\nRegards\nAmit Yadav')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Nabarangpur

Nabarangpur_NEFT = NEFT_Data.query('Name.str.startswith("Naba")', engine='python')
df1 = Nabarangpur_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Nabarangpur_NEFT = FE_Data.query('Name.str.startswith("Naba")', engine='python')
df2 = Nabarangpur_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Nabarangpur_Raw = pd.concat(df3)
Raw_Data = Nabarangpur_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'lakshmi.nayak@agrevolution.in'
cc = 'pratyushak.pradhan@agrevolution.in'
file_name = 'Nabarangpur.csv'


msg = EmailMessage()
msg['Subject'] = 'Nabarangpur || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Laxmi Narayan Nayak,\nPlease find below attachment of UTR of Nabarangpur.\n\n\n\nRegards\nAmit Yadav')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Burdwan

Burdwan_NEFT = NEFT_Data.query('Name.str.startswith("Burd")', engine='python')
df1 = Burdwan_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Burdwan_NEFT = FE_Data.query('Name.str.startswith("Burd")', engine='python')
df2 = Burdwan_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Burdwan_Raw = pd.concat(df3)
Raw_Data = Burdwan_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'sourav.roy@agrevolution.in'
cc = 'pratyushak.pradhan@agrevolution.in'
file_name = 'Burdwan.csv'


msg = EmailMessage()
msg['Subject'] = 'Burdwan || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Sourav Roy,\nPlease find below attachment of UTR of Burdwan.\n\n\n\nRegards\nAmit Yadav')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Cooch Behar

CoochBehar_NEFT = NEFT_Data.query('Name.str.startswith("Cooc")', engine='python')
df1 = CoochBehar_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
CoochBehar_NEFT = FE_Data.query('Name.str.startswith("Cooc")', engine='python')
df2 = CoochBehar_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
CoochBehar_Raw = pd.concat(df3)
Raw_Data = CoochBehar_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'pritam.datta@agrevolution.in'
cc = 'pratyushak.pradhan@agrevolution.in'
file_name = 'CoochBehar.csv'


msg = EmailMessage()
msg['Subject'] = 'CoochBehar || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Pritam Dutta,\nPlease find below attachment of UTR of CoochBehar.\n\n\n\nRegards\nAmit Yadav')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#East medinipur

Eastmedinipur_NEFT = NEFT_Data.query('Name.str.startswith("East")', engine='python')
df1 = Eastmedinipur_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Eastmedinipur_NEFT = FE_Data.query('Name.str.startswith("East")', engine='python')
df2 = Eastmedinipur_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Eastmedinipur_Raw = pd.concat(df3)
Raw_Data = Eastmedinipur_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'biswajit.swain@agrevolution.in'
cc = 'pratyushak.pradhan@agrevolution.in'
file_name = 'Eastmedinipur.csv'


msg = EmailMessage()
msg['Subject'] = 'Eastmedinipur || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Biswajit Swain,\nPlease find below attachment of UTR of Eastmedinipur.\n\n\n\nRegards\nAmit Yadav')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Hooghly

Hooghly_NEFT = NEFT_Data.query('Name.str.startswith("Hoog")', engine='python')
df1 = Hooghly_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Hooghly_NEFT = FE_Data.query('Name.str.startswith("Hoog")', engine='python')
df2 = Hooghly_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Hooghly_Raw = pd.concat(df3)
Raw_Data = Hooghly_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'pankaj.bera@agrevolution.in'
cc = 'pratyushak.pradhan@agrevolution.in'
file_name = 'Hooghly.csv'


msg = EmailMessage()
msg['Subject'] = 'Hooghly || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi pankaj bera,\nPlease find below attachment of UTR of Hooghly.\n\n\n\nRegards\nAmit Yadav')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Krishnanagar (HQ)

Krishnanagar_NEFT = NEFT_Data.query('Name.str.startswith("Kris")', engine='python')
df1 = Krishnanagar_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Krishnanagar_NEFT = FE_Data.query('Name.str.startswith("Kris")', engine='python')
df2 = Krishnanagar_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Krishnanagar_Raw = pd.concat(df3)
Raw_Data = Krishnanagar_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'avijit.sil@agrevolution.in'
cc = 'pratyushak.pradhan@agrevolution.in'
file_name = 'Krishnanagar.csv'


msg = EmailMessage()
msg['Subject'] = 'Krishnanagar || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Avijit Sil,\nPlease find below attachment of UTR of Krishnanagar.\n\n\n\nRegards\nAmit Yadav')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Malda

Malda_NEFT = NEFT_Data.query('Name.str.startswith("Mald")', engine='python')
df1 = Malda_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Malda_NEFT = FE_Data.query('Name.str.startswith("Mald")', engine='python')
df2 = Malda_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Malda_Raw = pd.concat(df3)
Raw_Data = Malda_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'chotan.mandal@agrevolution.in'
cc = 'pratyushak.pradhan@agrevolution.in'
file_name = 'Malda.csv'


msg = EmailMessage()
msg['Subject'] = 'Malda || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Choton Mondal,\nPlease find below attachment of UTR of Malda.\n\n\n\nRegards\nAmit Yadav')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Murshidabad

Murshidabad_NEFT = NEFT_Data.query('Name.str.startswith("Murs")', engine='python')
df1 = Murshidabad_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Murshidabad_NEFT = FE_Data.query('Name.str.startswith("Mursh")', engine='python')
df2 = Murshidabad_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Murshidabad_Raw = pd.concat(df3)
Raw_Data = Murshidabad_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'satya.tiwari@agrevolution.in'
cc = 'pratyushak.pradhan@agrevolution.in'
file_name = 'Murshidabad.csv'


msg = EmailMessage()
msg['Subject'] = 'Murshidabad || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Satya Prakash Tiwari,\nPlease find below attachment of UTR of Murshidabad.\n\n\n\nRegards\nAmit Yadav')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
time.sleep(300)

# %%
#North 24 Parganas

North24Parganas_NEFT = NEFT_Data.query('Name.str.startswith("Nort")', engine='python')
df1 = North24Parganas_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
North24Parganas_NEFT = FE_Data.query('Name.str.startswith("Nort")', engine='python')
df2 = North24Parganas_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
North24Parganas_Raw = pd.concat(df3)
Raw_Data = North24Parganas_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'debashish.mondal@agrevolution.in'
cc = 'pratyushak.pradhan@agrevolution.in'
file_name = 'North24Parganas.csv'


msg = EmailMessage()
msg['Subject'] = 'North 24 Parganas || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi debashish mondal,\nPlease find below attachment of UTR of North 24 Parganas.\n\n\n\nRegards\nAmit Yadav')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#West Medinipur

WestMedinipur_NEFT = NEFT_Data.query('Name.str.startswith("Wes")', engine='python')
df1 = WestMedinipur_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
WestMedinipur_NEFT = FE_Data.query('Name.str.startswith("Wes")', engine='python')
df2 = WestMedinipur_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
WestMedinipur_Raw = pd.concat(df3)
Raw_Data = WestMedinipur_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'soumen.ganguly@agrevolution.in'
cc = 'pratyushak.pradhan@agrevolution.in'
file_name = 'WestMedinipur.csv'


msg = EmailMessage()
msg['Subject'] = 'West Medinipur || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Soumen Ganguly,\nPlease find below attachment of UTR of West Medinipur.\n\n\n\nRegards\nAmit Yadav')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Gorakhpur

Gorakhpur_NEFT = NEFT_Data.query('Name.str.startswith("Gora")', engine='python')
df1 = Gorakhpur_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Gorakhpur_NEFT = FE_Data.query('Name.str.startswith("Gora")', engine='python')
df2 = Gorakhpur_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Gorakhpur_Raw = pd.concat(df3)
Raw_Data = Gorakhpur_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'shubham.pandey@agrevolution.in'
cc = 'raghvendra.tripathi@agrevolution.in'
file_name = 'Gorakhpur.csv'


msg = EmailMessage()
msg['Subject'] = 'Gorakhpur || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Shubham Pandey,\nPlease find below attachment of UTR of Gorakhpur.\n\n\n\nRegards\nAmit Yadav')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Rajkot

Rajkot_NEFT = NEFT_Data.query('Name.str.startswith("Rajk")', engine='python')
df1 = Rajkot_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Rajkot_NEFT = FE_Data.query('Name.str.startswith("Raj")', engine='python')
df2 = Rajkot_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Rajkot_Raw = pd.concat(df3)
Raw_Data = Rajkot_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'Joshi.Tejasbhai@agrevolution.in'
cc = 'vishal.joshi@agrevolution.in'
file_name = 'Rajkot.csv'


msg = EmailMessage()
msg['Subject'] = 'Rajkot || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Tejash Joshi,\nPlease find below attachment of UTR of Rajkot.\n\n\n\nRegards\nAmit Yadav')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Junagadh

Junagadh_NEFT = NEFT_Data.query('Name.str.startswith("Juna")', engine='python')
df1 = Junagadh_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Junagadh_NEFT = FE_Data.query('Name.str.startswith("Juna")', engine='python')
df2 = Junagadh_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Junagadh_Raw = pd.concat(df3)
Raw_Data = Junagadh_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'bhatt.kaushal@agrevolution.in'
cc = 'vishal.joshi@agrevolution.in'
file_name = 'Junagadh.csv'


msg = EmailMessage()
msg['Subject'] = 'Junagadh || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Bhatt Kaushal Kanaiyalal,\nPlease find below attachment of UTR of Junagadh.\n\n\n\nRegards\nAmit Yadav')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Ahmedabad

Ahmedabad_NEFT = NEFT_Data.query('Name.str.startswith("Ahmeda")', engine='python')
df1 = Ahmedabad_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Ahmedabad_NEFT = FE_Data.query('Name.str.startswith("Ahmeda")', engine='python')
df2 = Ahmedabad_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Ahmedabad_Raw = pd.concat(df3)
Raw_Data = Ahmedabad_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'bhatt.kaushal@agrevolution.in'
cc = 'vishal.joshi@agrevolution.in'
file_name = 'Ahmedabad.csv'


msg = EmailMessage()
msg['Subject'] = 'Ahmedabad || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Bhatt Kaushal Kanaiyalal,\nPlease find below attachment of UTR of Ahmedabad.\n\n\n\nRegards\nAmit Yadav')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Nanded

Nanded_NEFT = NEFT_Data.query('Name.str.startswith("Nand")', engine='python')
df1 = Nanded_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Nanded_NEFT = FE_Data.query('Name.str.startswith("Nand")', engine='python')
df2 = Nanded_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Nanded_Raw = pd.concat(df3)
Raw_Data = Nanded_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'kokare.bhimrao@agrevolution.in'
cc = 'ranjan.gudmeti@agrevolution.in'
file_name = 'Nanded.csv'


msg = EmailMessage()
msg['Subject'] = 'Nanded || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Kiran Bhimrao Kokare,\nPlease find below attachment of UTR of Nanded.\n\n\n\nRegards\nAmit Yadav')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Hisar
Hisar_NEFT = NEFT_Data.query('Name.str.startswith("Hisa")', engine='python')
df1 = Hisar_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Hisar_NEFT = FE_Data.query('Name.str.startswith("Hisa")', engine='python')
df2 = Hisar_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Hisar_Raw = pd.concat(df3)
Raw_Data = Hisar_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'arpit.vashistha@agrevolution.in'
cc = 'shakti.singh@agrevolution.in'
file_name = 'Hisar.csv'


msg = EmailMessage()
msg['Subject'] = 'Hisar || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Arpit Vasist ,\nPlease find below attachment of UTR of Hisar.\n\n\n\nRegards\nAmit Yadav')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Jodhpur
Jodhpur_NEFT = NEFT_Data.query('Name.str.startswith("Jodh")', engine='python')
df1 = Jodhpur_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Jodhpur_NEFT = FE_Data.query('Name.str.startswith("Jodh")', engine='python')
df2 = Jodhpur_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Jodhpur_Raw = pd.concat(df3)
Raw_Data = Jodhpur_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'prince.pareek@agrevolution.in'
cc = 'vikash.mishra@agrevolution.in'
file_name = 'Jodhpur.csv'


msg = EmailMessage()
msg['Subject'] = 'Jodhpur || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Rahul Mali,\nPlease find below attachment of UTR of Jodhpur.\n\n\n\nRegards\nAmit Yadav')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Hanumangarh
Hanumangarh_NEFT = NEFT_Data.query('Name.str.startswith("Hanu")', engine='python')
df1 = Hanumangarh_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Hanumangarh_NEFT = FE_Data.query('Name.str.startswith("Hanu")', engine='python')
df2 = Hanumangarh_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Hanumangarh_Raw = pd.concat(df3)
Raw_Data = Hanumangarh_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'satyanarayan.sharma@agrevolution.in'
cc = 'vikash.mishra@agrevolution.in'
file_name = 'Hanumangarh.csv'


msg = EmailMessage()
msg['Subject'] = 'Hanumangarh || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Satyanarayan,\nPlease find below attachment of UTR of Hanumangarh.\n\n\n\nRegards\nAmit Yadav')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Kota
Kota_NEFT = NEFT_Data.query('Name.str.startswith("Kota")', engine='python')
df1 = Kota_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Kota_NEFT = FE_Data.query('Name.str.startswith("Kota")', engine='python')
df2 = Kota_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Kota_Raw = pd.concat(df3)
Raw_Data = Kota_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'rajendra.meghwal@agrevolution.in'
cc = 'vikash.mishra@agrevolution.in'
file_name = 'Kota.csv'


msg = EmailMessage()
msg['Subject'] = 'Kota || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Rajendra Kumar Meghwal,\nPlease find below attachment of UTR of Kota.\n\n\n\nRegards\nAmit Yadav')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Jaipur
Jaipur_NEFT = NEFT_Data.query('Name.str.startswith("Jaip")', engine='python')
df1 = Jaipur_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Jaipur_NEFT = FE_Data.query('Name.str.startswith("Jaip")', engine='python')
df2 = Jaipur_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Jaipur_Raw = pd.concat(df3)
Raw_Data = Jaipur_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'abhishekp.pareek@agrevolution.in'
cc = 'vikash.mishra@agrevolution.in'
file_name = 'Jaipur.csv'


msg = EmailMessage()
msg['Subject'] = 'Jaipur || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Abhishek Pareek,\nPlease find below attachment of UTR of Jaipur.\n\n\n\nRegards\nAmit Yadav')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Dewas
Dewas_NEFT = NEFT_Data.query('Name.str.startswith("Dewa")', engine='python')
df1 = Dewas_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Dewas_NEFT = FE_Data.query('Name.str.startswith("Dewa")', engine='python')
df2 = Dewas_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Dewas_Raw = pd.concat(df3)
Raw_Data = Dewas_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'santosh.goswami@agrevolution.in'
cc = 'sunil.mishra2@agrevolution.in'
file_name = 'Dewas.csv'


msg = EmailMessage()
msg['Subject'] = 'Dewas || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Santosh Goswami,\nPlease find below attachment of UTR of Dewas.\n\n\n\nRegards\nAmit Yadav')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Indore
Indore_NEFT = NEFT_Data.query('Name.str.startswith("Indo")', engine='python')
df1 = Indore_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Indore_NEFT = FE_Data.query('Name.str.startswith("Indo")', engine='python')
df2 = Indore_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Indore_Raw = pd.concat(df3)
Raw_Data = Indore_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'rajat.sahu@agrevolution.in'
cc = 'sunil.mishra2@agrevolution.in'
file_name = 'Indore.csv'


msg = EmailMessage()
msg['Subject'] = 'Indore || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Rajat Sahu,\nPlease find below attachment of UTR of Indore.\n\n\n\nRegards\nAmit Yadav')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Dhar
Dhar_NEFT = NEFT_Data.query('Name.str.startswith("Dhar")', engine='python')
df1 = Dhar_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Dhar_NEFT = FE_Data.query('Name.str.startswith("Dhar")', engine='python')
df2 = Dhar_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Dhar_Raw = pd.concat(df3)
Raw_Data = Dhar_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'sandeep.choyal@agrevolution.in'
cc = 'sunil.mishra2@agrevolution.in'
file_name = 'Dhar.csv'


msg = EmailMessage()
msg['Subject'] = 'Dhar || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Sandeep Choyal,\nPlease find below attachment of UTR of Dhar.\n\n\n\nRegards\nAmit Yadav')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Alwar
Alwar_NEFT = NEFT_Data.query('Name.str.startswith("Alwa")', engine='python')
df1 = Alwar_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Alwar_NEFT = FE_Data.query('Name.str.startswith("Alwa")', engine='python')
df2 = Alwar_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Alwar_Raw = pd.concat(df3)
Raw_Data = Alwar_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'ved.saini@agrevolution.in'
cc = 'vikash.mishra@agrevolution.in'
file_name = 'Alwar.csv'


msg = EmailMessage()
msg['Subject'] = 'Alwar || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Vedprakash Saini,\nPlease find below attachment of UTR of Alwar.\n\n\n\nRegards\nAmit Yadav')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Ratlam
Ratlam_NEFT = NEFT_Data.query('Name.str.startswith("Ratl")', engine='python')
df1 = Ratlam_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Ratlam_NEFT = FE_Data.query('Name.str.startswith("Ratl")', engine='python')
df2 = Ratlam_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Ratlam_Raw = pd.concat(df3)
Raw_Data = Ratlam_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'devendra.timecha@agrevolution.in'
cc = 'sunil.mishra2@agrevolution.in'
file_name = 'Ratlam.csv'


msg = EmailMessage()
msg['Subject'] = 'Ratlam || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Devendra Timecha,\nPlease find below attachment of UTR of Ratlam.\n\n\n\nRegards\nAmit Yadav')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Barwani
Barwani_NEFT = NEFT_Data.query('Name.str.startswith("Barw")', engine='python')
df1 = Barwani_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Barwani_NEFT = FE_Data.query('Name.str.startswith("Barw")', engine='python')
df2 = Barwani_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Barwani_Raw = pd.concat(df3)
Raw_Data = Barwani_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'sandeep.choyal@agrevolution.in'
cc = 'sunil.mishra2@agrevolution.in'
file_name = 'Barwani.csv'


msg = EmailMessage()
msg['Subject'] = 'Barwani || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Sandeep Choyal,\nPlease find below attachment of UTR of Barwani.\n\n\n\nRegards\nAmit Yadav')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Shajapur
Shajapur_NEFT = NEFT_Data.query('Name.str.startswith("Shaj")', engine='python')
df1 = Shajapur_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Shajapur_NEFT = FE_Data.query('Name.str.startswith("Shaj")', engine='python')
df2 = Shajapur_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Shajapur_Raw = pd.concat(df3)
Raw_Data = Shajapur_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'santosh.goswami@agrevolution.in'
cc = 'sunil.mishra2@agrevolution.in'
file_name = 'Shajapur.csv'


msg = EmailMessage()
msg['Subject'] = 'Shajapur || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Santosh Goswami,\nPlease find below attachment of UTR of Shajapur.\n\n\n\nRegards\nAmit Yadav')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Hoshangabad
Hoshangabad_NEFT = NEFT_Data.query('Name.str.startswith("Hosh")', engine='python')
df1 = Hoshangabad_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Hoshangabad_NEFT = FE_Data.query('Name.str.startswith("Hosh")', engine='python')
df2 = Hoshangabad_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Hoshangabad_Raw = pd.concat(df3)
Raw_Data = Hoshangabad_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'prashant.sapkale@agrevolution.in'
cc = 'sunil.mishra2@agrevolution.in'
file_name = 'Hoshangabad.csv'


msg = EmailMessage()
msg['Subject'] = 'Hoshangabad || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Prashant Sapkale,\nPlease find below attachment of UTR of Hoshangabad.\n\n\n\nRegards\nAmit Yadav')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Chhindwara
Chhindwara_NEFT = NEFT_Data.query('Name.str.startswith("Chhi")', engine='python')
df1 = Chhindwara_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Chhindwara_NEFT = FE_Data.query('Name.str.startswith("Chhi")', engine='python')
df2 = Chhindwara_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Chhindwara_Raw = pd.concat(df3)
Raw_Data = Chhindwara_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'deepak.kaslekar@agrevolution.in'
cc = 'sunil.mishra2@agrevolution.in'
file_name = 'Chhindwara.csv'


msg = EmailMessage()
msg['Subject'] = 'Chhindwara || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Deepak Kaslekar,\nPlease find below attachment of UTR of Chhindwara.\n\n\n\nRegards\nAmit Yadav')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)
