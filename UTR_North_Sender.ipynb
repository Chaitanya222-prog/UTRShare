# %%
#auth.authenticate_user()
from gspread_dataframe import set_with_dataframe
#from geopy.geocoders import Nominatim
#from geopy import distance
import gspread
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import seaborn as sns
#sns.set()
#from sklearn.cluster import KMeans
from datetime import datetime, timedelta
#from oauth2client.client import GoogleCredentials

from google.oauth2.service_account import Credentials

#gc = gspread.service_account(filename="/content/creds.json")
import smtplib
from smtplib import SMTPException
from email.message import EmailMessage
from datetime import date
from datetime import datetime, timedelta
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.base import MIMEBase
from email import encoders
from email.message import EmailMessage
from tabulate import tabulate

# %%
scopes = [
    'https://www.googleapis.com/auth/spreadsheets',
    'https://www.googleapis.com/auth/drive'
]
credentials = Credentials.from_service_account_file(
    '/content/secret_key.json',
    scopes=scopes
)
gc = gspread.authorize(credentials)

# %%
NEFT_Data = pd.DataFrame.from_records(gc.open('UTR_Mail_Push').worksheet('NEFT_Final').get_all_records())
FE_Data = pd.DataFrame.from_records(gc.open('UTR_Mail_Push').worksheet('FE_Final').get_all_records())

# %%
#Agra

Agra_NEFT = NEFT_Data.query('Name.str.startswith("Agra")', engine='python')
df1 = Agra_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Agra_NEFT = FE_Data.query('Name.str.startswith("Agra")', engine='python')
df2 = Agra_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Agra_Raw = pd.concat(df3)
Raw_Data = Agra_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'rupendra.kumar@agrevolution.in'
cc = 'anoop.arela@agrevolution.in'
file_name = 'Agra.csv'


msg = EmailMessage()
msg['Subject'] = 'Agra || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Rupendra,\nPlease find below attachment of UTR of Agra.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Bahraich

Bahraich_NEFT = NEFT_Data.query('Name.str.startswith("Bahr")', engine='python')
df1 = Bahraich_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Bahraich_NEFT = FE_Data.query('Name.str.startswith("Bahr")', engine='python')
df2 = Bahraich_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Bahraich_Raw = pd.concat(df3)
Raw_Data = Bahraich_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'navneet.dubey@agrevolution.in'
cc = 'bhupesh.ranjan@agrevolution.in'
file_name = 'Bahraich.csv'


msg = EmailMessage()
msg['Subject'] = 'Bahraich || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Navneet Dubey,\nPlease find below attachment of UTR of Bahraich.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Kushinagar

Kushinagar_NEFT = NEFT_Data.query('Name.str.startswith("Kush")', engine='python')
df1 = Kushinagar_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Kushinagar_NEFT = FE_Data.query('Name.str.startswith("Kush")', engine='python')
df2 = Kushinagar_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Kushinagar_Raw = pd.concat(df3)
Raw_Data = Kushinagar_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'rahul.singh2@agrevolution.in'
cc = 'raghvendra.tripathi@agrevolution.in'
file_name = 'Kushinagar.csv'


msg = EmailMessage()
msg['Subject'] = 'Kushinagar || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Rahul,\nPlease find below attachment of UTR of Kushinagar.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Jaunpur

Jaunpur_NEFT = NEFT_Data.query('Name.str.startswith("Jaun")', engine='python')
df1 = Jaunpur_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Jaunpur_NEFT = FE_Data.query('Name.str.startswith("Jaun")', engine='python')
df2 = Jaunpur_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Jaunpur_Raw = pd.concat(df3)
Raw_Data = Jaunpur_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'ashutosh.dwivedi@agrevolution.in'
cc = 'arun.kumar@agrevolution.in'
file_name = 'Jaunpur.csv'


msg = EmailMessage()
msg['Subject'] = 'Jaunpur || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Ashutosh Dwivedi,\nPlease find below attachment of UTR of Jaunpur.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Shahjahanpr

Shahjahanpr_NEFT = NEFT_Data.query('Name.str.startswith("Shah")', engine='python')
df1 = Shahjahanpr_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Shahjahanpr_NEFT = FE_Data.query('Name.str.startswith("Shah")', engine='python')
df2 = Shahjahanpr_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Shahjahanpr_Raw = pd.concat(df3)
Raw_Data = Shahjahanpr_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'arun.chauhan@agrevolution.in'
cc = 'sushobhit.sharma@agrevolution.in '
file_name = 'Shahjahanpr.csv'


msg = EmailMessage()
msg['Subject'] = 'Shahjahanpr || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Arun Chauhan,\nPlease find below attachment of UTR of Shahjahanpr.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Moradabad

Moradabad_NEFT = NEFT_Data.query('Name.str.startswith("Mora")', engine='python')
df1 = Moradabad_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Moradabad_NEFT = FE_Data.query('Name.str.startswith("Mora")', engine='python')
df2 = Moradabad_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Moradabad_Raw = pd.concat(df3)
Raw_Data = Moradabad_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'yogesh.kumar@agrevolution.in'
cc = 'sushobhit.sharma@agrevolution.in'
file_name = 'Moradabad.csv'


msg = EmailMessage()
msg['Subject'] = 'Moradabad || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Yogesh Kumar,\nPlease find below attachment of UTR of Moradabad.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Kasganj

Kasganj_NEFT = NEFT_Data.query('Name.str.startswith("Kasg")', engine='python')
df1 = Kasganj_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Kasganj_NEFT = FE_Data.query('Name.str.startswith("Kasg")', engine='python')
df2 = Kasganj_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Kasganj_Raw = pd.concat(df3)
Raw_Data = Kasganj_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'avadesh.rajpoot@agrevolution.in'
cc = 'anoop.arela@agrevolution.in'
file_name = 'Kasganj.csv'


msg = EmailMessage()
msg['Subject'] = 'Kasganj || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Avadesh Rajpoot,\nPlease find below attachment of UTR of Kasganj.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Farrukhabad

Farrukhabad_NEFT = NEFT_Data.query('Name.str.startswith("Farr")', engine='python')
df1 = Farrukhabad_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Farrukhabad_NEFT = FE_Data.query('Name.str.startswith("Farr")', engine='python')
df2 = Farrukhabad_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Farrukhabad_Raw = pd.concat(df3)
Raw_Data = Farrukhabad_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'sanjay.kumar@agrevolution.in'
cc = 'sushobhit.sharma@agrevolution.in'
file_name = 'Farrukhabad.csv'


msg = EmailMessage()
msg['Subject'] = 'Farrukhabad || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Sanjay Kumar,\nPlease find below attachment of UTR of Farrukhabad.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Hapur
Hapur_NEFT = NEFT_Data.query('Name.str.startswith("Hapu")', engine='python')
df1 = Hapur_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Hapur_NEFT = FE_Data.query('Name.str.startswith("Hapu")', engine='python')
df2 = Hapur_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Hapur_Raw = pd.concat(df3)
Raw_Data = Hapur_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'sonu.dhiman@agrevolution.in'
cc = 'sushobhit.sharma@agrevolution.in'
file_name = 'Hapur.csv'


msg = EmailMessage()
msg['Subject'] = 'Hapur || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Sonu Dhiman,\nPlease find below attachment of UTR of Hapur.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Sitapur

Sitapur_NEFT = NEFT_Data.query('Name.str.startswith("Sitap")', engine='python')
df1 = Sitapur_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Sitapur_NEFT = FE_Data.query('Name.str.startswith("Sitap")', engine='python')
df2 = Sitapur_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Sitapur_Raw = pd.concat(df3)
Raw_Data = Sitapur_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'ranjeet.kumar3@agrevolution.in'
cc = 'bhupesh.ranjan@agrevolution.in'
file_name = 'Sitapur.csv'


msg = EmailMessage()
msg['Subject'] = 'Sitapur || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Ranjeet Kumar,\nPlease find below attachment of UTR of Sitapur.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Hardoi

Hardoi_NEFT = NEFT_Data.query('Name.str.startswith("Hard")', engine='python')
df1 = Hardoi_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Hardoi_NEFT = FE_Data.query('Name.str.startswith("Hard")', engine='python')
df2 = Hardoi_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Hardoi_Raw = pd.concat(df3)
Raw_Data = Hardoi_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'balgovind@agrevolution.in'
cc = 'bhupesh.ranjan@agrevolution.in'
file_name = 'Hardoi.csv'


msg = EmailMessage()
msg['Subject'] = 'Hardoi || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Bal Govind,\nPlease find below attachment of UTR of Hardoi.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Faizabad
Faizabad_NEFT = NEFT_Data.query('Name.str.startswith("Faiz")', engine='python')
df1 = Faizabad_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Faizabad_NEFT = FE_Data.query('Name.str.startswith("Faiz")', engine='python')
df2 = Faizabad_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Faizabad_Raw = pd.concat(df3)
Raw_Data = Faizabad_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'pankaj.verma@agrevolution.in'
cc = 'bhupesh.ranjan@agrevolution.in'
file_name = 'Faizabad.csv'


msg = EmailMessage()
msg['Subject'] = 'Faizabad || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Pankaj Verma,\nPlease find below attachment of UTR of Faizabad.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Sonbhadra
Sonbhadra_NEFT = NEFT_Data.query('Name.str.startswith("Sonb")', engine='python')
df1 = Sonbhadra_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Sonbhadra_NEFT = FE_Data.query('Name.str.startswith("Sonb")', engine='python')
df2 = Sonbhadra_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Sonbhadra_Raw = pd.concat(df3)
Raw_Data = Sonbhadra_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'rajesh.yadav@agrevolution.in'
cc = 'arun.kumar@agrevolution.in'
file_name = 'Sonbhadra.csv'


msg = EmailMessage()
msg['Subject'] = 'Sonbhadra || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Rajesh Yadav,\nPlease find below attachment of UTR of Sonbhadra.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Ghazipur
Ghazipur_NEFT = NEFT_Data.query('Name.str.startswith("Ghaz")', engine='python')
df1 = Ghazipur_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Ghazipur_NEFT = FE_Data.query('Name.str.startswith("Ghaz")', engine='python')
df2 = Ghazipur_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Ghazipur_Raw = pd.concat(df3)
Raw_Data = Ghazipur_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'saddam.husain@agrevolution.in'
cc = 'raghvendra.tripathi@agrevolution.in'
file_name = 'Ghazipur.csv'


msg = EmailMessage()
msg['Subject'] = 'Ghazipur || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Saddam Husain,\nPlease find below attachment of UTR of Ghazipur.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Kheri
Kheri_NEFT = NEFT_Data.query('Name.str.startswith("Kher")', engine='python')
df1 = Kheri_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Kheri_NEFT = FE_Data.query('Name.str.startswith("Kher")', engine='python')
df2 = Kheri_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Kheri_Raw = pd.concat(df3)
Raw_Data = Kheri_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'vijay.shukla@agrevolution.in'
cc = 'bhupesh.ranjan@agrevolution.in'
file_name = 'Kheri.csv'


msg = EmailMessage()
msg['Subject'] = 'Kheri || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Amit Dubey,\nPlease find below attachment of UTR of Kheri.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Aligarh
Aligarh_NEFT = NEFT_Data.query('Name.str.startswith("Alig")', engine='python')
df1 = Aligarh_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Aligarh_NEFT = FE_Data.query('Name.str.startswith("Alig")', engine='python')
df2 = Aligarh_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Aligarh_Raw = pd.concat(df3)
Raw_Data = Aligarh_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'rajat.gupta@agrevolution.in'
cc = 'anoop.arela@agrevolution.in'
file_name = 'Aligarh.csv'


msg = EmailMessage()
msg['Subject'] = 'Aligarh || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Rajat Gupta,\nPlease find below attachment of UTR of Aligarh.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Ballia
Ballia_NEFT = NEFT_Data.query('Name.str.startswith("Ball")', engine='python')
df1 = Ballia_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Ballia_NEFT = FE_Data.query('Name.str.startswith("Ball")', engine='python')
df2 = Ballia_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Ballia_Raw = pd.concat(df3)
Raw_Data = Ballia_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'shivmuni.yadav@agrevolution.in'
cc = 'raghvendra.tripathi@agrevolution.in'
file_name = 'Ballia.csv'


msg = EmailMessage()
msg['Subject'] = 'Ballia || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Shivmuni Yadav,\nPlease find below attachment of UTR of Ballia.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Allahabad
Allahabad_NEFT = NEFT_Data.query('Name.str.startswith("Alla")', engine='python')
df1 = Allahabad_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Allahabad_NEFT = FE_Data.query('Name.str.startswith("Alla")', engine='python')
df2 = Allahabad_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Allahabad_Raw = pd.concat(df3)
Raw_Data = Allahabad_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'harshit.tiwari@agrevolution.in'
cc = 'arun.kumar@agrevolution.in'
file_name = 'Allahabad.csv'


msg = EmailMessage()
msg['Subject'] = 'Allahabad || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Harshit Tiwari,\nPlease find below attachment of UTR of Allahabad.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Bulandshahr
Bulandshahr_NEFT = NEFT_Data.query('Name.str.startswith("Bula")', engine='python')
df1 = Bulandshahr_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Bulandshahr_NEFT = FE_Data.query('Name.str.startswith("Bula")', engine='python')
df2 = Bulandshahr_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Bulandshahr_Raw = pd.concat(df3)
Raw_Data = Bulandshahr_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'balveer.goswami@agrevolution.in'
cc = 'anoop.arela@agrevolution.in'
file_name = 'Bulandshahr.csv'


msg = EmailMessage()
msg['Subject'] = 'Bulandshahr || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Balveer Goswami,\nPlease find below attachment of UTR of Bulandshahr.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Varanasi
Varanasi_NEFT = NEFT_Data.query('Name.str.startswith("Vara")', engine='python')
df1 = Varanasi_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Varanasi_NEFT = FE_Data.query('Name.str.startswith("Vara")', engine='python')
df2 = Varanasi_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Varanasi_Raw = pd.concat(df3)
Raw_Data = Varanasi_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'shreyash.tripathi@agrevolution.in'
cc = 'arun.kumar@agrevolution.in'
file_name = 'Varanasi.csv'


msg = EmailMessage()
msg['Subject'] = 'Varanasi || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Shreyash Tripathi,\nPlease find below attachment of UTR of Varanasi.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Bareilly
Bareilly_NEFT = NEFT_Data.query('Name.str.startswith("Bare")', engine='python')
df1 = Bareilly_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Bareilly_NEFT = FE_Data.query('Name.str.startswith("Bare")', engine='python')
df2 = Bareilly_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Bareilly_Raw = pd.concat(df3)
Raw_Data = Bareilly_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'pushpendra.singh@agrevolution.in'
cc = 'sushobhit.sharma@agrevolution.in'
file_name = 'Bareilly.csv'


msg = EmailMessage()
msg['Subject'] = 'Bareilly || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Pushpendra Singh,\nPlease find below attachment of UTR of Bareilly.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Amroha
Amroha_NEFT = NEFT_Data.query('Name.str.startswith("Amro")', engine='python')
df1 = Amroha_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Amroha_NEFT = FE_Data.query('Name.str.startswith("Amro")', engine='python')
df2 = Amroha_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Amroha_Raw = pd.concat(df3)
Raw_Data = Amroha_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'somnath.thakur@agrevolution.in'
cc = 'sushobhit.sharma@agrevolution.in'
file_name = 'Amroha.csv'


msg = EmailMessage()
msg['Subject'] = 'Amroha || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Somnath,\nPlease find below attachment of UTR of Amroha.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Barabanki
Barabanki_NEFT = NEFT_Data.query('Name.str.startswith("Bara")', engine='python')
df1 = Barabanki_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Barabanki_NEFT = FE_Data.query('Name.str.startswith("Bara")', engine='python')
df2 = Barabanki_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Barabanki_Raw = pd.concat(df3)
Raw_Data = Barabanki_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'amit.kumar3@agrevolution.in'
cc = 'bhupesh.ranjan@agrevolution.in'
file_name = 'Barabanki.csv'


msg = EmailMessage()
msg['Subject'] = 'Barabanki || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Amit Kumar,\nPlease find below attachment of UTR of Barabanki.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Sikar
Sikar_NEFT = NEFT_Data.query('Name.str.startswith("Sika")', engine='python')
df1 = Sikar_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Sikar_NEFT = FE_Data.query('Name.str.startswith("Sika")', engine='python')
df2 = Sikar_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Sikar_Raw = pd.concat(df3)
Raw_Data = Sikar_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'manoj.kumar2@agrevolution.in'
cc = 'vikash.mishra@agrevolution.in'
file_name = 'Sikar.csv'


msg = EmailMessage()
msg['Subject'] = 'Sikar || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Manoj Kumar,\nPlease find below attachment of UTR of Sikar.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)
