# %%
#auth.authenticate_user()
from gspread_dataframe import set_with_dataframe
#from geopy.geocoders import Nominatim
#from geopy import distance
import gspread
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import seaborn as sns
#sns.set()
#from sklearn.cluster import KMeans
from datetime import datetime, timedelta
#from oauth2client.client import GoogleCredentials

from google.oauth2.service_account import Credentials

#gc = gspread.service_account(filename="/content/creds.json")
import smtplib
from smtplib import SMTPException
from email.message import EmailMessage
from datetime import date
from datetime import datetime, timedelta
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.base import MIMEBase
from email import encoders
from email.message import EmailMessage
from tabulate import tabulate

# %%
scopes = [
    'https://www.googleapis.com/auth/spreadsheets',
    'https://www.googleapis.com/auth/drive'
]
credentials = Credentials.from_service_account_file(
    '/content/secret_key.json',
    scopes=scopes
)
gc = gspread.authorize(credentials)

# %%
NEFT_Data = pd.DataFrame.from_records(gc.open('UTR_Mail_Push').worksheet('NEFT_Final').get_all_records())
FE_Data = pd.DataFrame.from_records(gc.open('UTR_Mail_Push').worksheet('FE_Final').get_all_records())

# %%
#Solapur

Solapur_NEFT = NEFT_Data.query('Name.str.startswith("Sola")', engine='python')
df1 = Solapur_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Solapur_NEFT = FE_Data.query('Name.str.startswith("Sola")', engine='python')
df2 = Solapur_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Solapur_Raw = pd.concat(df3)
Raw_Data = Solapur_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'ajay.jadhav@agrevolution.in'
cc = 'sandeep.pawar@agrevolution.in'
file_name = 'Solapur.csv'


msg = EmailMessage()
msg['Subject'] = 'Solapur || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Ajay jadhav,\nPlease find below attachment of UTR of Solapur.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Amravati

Amravati_NEFT = NEFT_Data.query('Name.str.startswith("Amra")', engine='python')
df1 = Amravati_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Amravati_NEFT = FE_Data.query('Name.str.startswith("Amra")', engine='python')
df2 = Amravati_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Amravati_Raw = pd.concat(df3)
Raw_Data = Amravati_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'pankaj.ashtikar@agrevolution.in'
cc = 'pramod.bachhao@agrevolution.in'
file_name = 'Amravati.csv'


msg = EmailMessage()
msg['Subject'] = 'Amravati || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Pankaj Astikar,\nPlease find below attachment of UTR of Amravati.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Buldhana

Buldhana_NEFT = NEFT_Data.query('Name.str.startswith("Buld")', engine='python')
df1 = Buldhana_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Buldhana_NEFT = FE_Data.query('Name.str.startswith("Buld")', engine='python')
df2 = Buldhana_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Buldhana_Raw = pd.concat(df3)
Raw_Data = Buldhana_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'anwar.khan@agrevolution.in'
cc = 'pramod.bachhao@agrevolution.in'
file_name = 'Buldhana.csv'


msg = EmailMessage()
msg['Subject'] = 'Buldhana || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Anwar Khan,\nPlease find below attachment of UTR of Buldhana.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Sangli

Sangli_NEFT = NEFT_Data.query('Name.str.startswith("Sang")', engine='python')
df1 = Sangli_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Sangli_NEFT = FE_Data.query('Name.str.startswith("Sang")', engine='python')
df2 = Sangli_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Sangli_Raw = pd.concat(df3)
Raw_Data = Sangli_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'vijay.boinwad@agrevolution.in'
cc = 'sandeep.pawar@agrevolution.in'
file_name = 'Sangli.csv'


msg = EmailMessage()
msg['Subject'] = 'Sangli || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Vijay M Boinwad,\nPlease find below attachment of UTR of Sangli.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Pune

Pune_NEFT = NEFT_Data.query('Name.str.startswith("Pune")', engine='python')
df1 = Pune_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Pune_NEFT = FE_Data.query('Name.str.startswith("Pune")', engine='python')
df2 = Pune_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Pune_Raw = pd.concat(df3)
Raw_Data = Pune_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'vishal.bidwe@agrevolution.in'
cc = 'ranjan.gudmeti@agrevolution.in'
file_name = 'Pune.csv'


msg = EmailMessage()
msg['Subject'] = 'Pune || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Vishal Vilas Bidwe,\nPlease find below attachment of UTR of Pune.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Satara

Satara_NEFT = NEFT_Data.query('Name.str.startswith("Sata")', engine='python')
df1 = Satara_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Satara_NEFT = FE_Data.query('Name.str.startswith("Sata")', engine='python')
df2 = Satara_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Satara_Raw = pd.concat(df3)
Raw_Data = Satara_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'maruti.chavan@agrevolution.in'
cc = 'ranjan.gudmeti@agrevolution.in'
file_name = 'Satara.csv'


msg = EmailMessage()
msg['Subject'] = 'Satara || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Maruti Satappa Chavan,\nPlease find below attachment of UTR of Satara.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Akola

Akola_NEFT = NEFT_Data.query('Name.str.startswith("Akol")', engine='python')
df1 = Akola_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Akola_NEFT = FE_Data.query('Name.str.startswith("Akol")', engine='python')
df2 = Akola_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Akola_Raw = pd.concat(df3)
Raw_Data = Akola_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'niraj.deshmukh@agrevolution.in'
cc = 'pramod.bachhao@agrevolution.in'
file_name = 'Akola.csv'


msg = EmailMessage()
msg['Subject'] = 'Akola || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Niraj Deshmukh,\nPlease find below attachment of UTR of Akola.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Nashik

Nashik_NEFT = NEFT_Data.query('Name.str.startswith("Nash")', engine='python')
df1 = Nashik_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Nashik_NEFT = FE_Data.query('Name.str.startswith("Nash")', engine='python')
df2 = Nashik_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Nashik_Raw = pd.concat(df3)
Raw_Data = Nashik_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'siddhant.jagtap@agrevolution.in'
cc = 'sahilv.gadhe@agrevolution.in'
file_name = 'Nashik.csv'


msg = EmailMessage()
msg['Subject'] = 'Nashik || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Siddhant Arvind jagtap,\nPlease find below attachment of UTR of Nashik.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Yavatmal

Yavatmal_NEFT = NEFT_Data.query('Name.str.startswith("Yava")', engine='python')
df1 = Yavatmal_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Yavatmal_NEFT = FE_Data.query('Name.str.startswith("Yava")', engine='python')
df2 = Yavatmal_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Yavatmal_Raw = pd.concat(df3)
Raw_Data = Yavatmal_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'ishwar.tavekar@agrevolution.in'
cc = 'pramod.bachhao@agrevolution.in'
file_name = 'Yavatmal.csv'


msg = EmailMessage()
msg['Subject'] = 'Yavatmal || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi ISHWAR TAVEKAR,\nPlease find below attachment of UTR of Yavatmal.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Hingoli

Hingoli_NEFT = NEFT_Data.query('Name.str.startswith("Hing")', engine='python')
df1 = Hingoli_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Hingoli_NEFT = FE_Data.query('Name.str.startswith("Hing")', engine='python')
df2 = Hingoli_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Hingoli_Raw = pd.concat(df3)
Raw_Data = Hingoli_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'kiran.paikrao@agrevolution.in'
cc = 'sahilv.gadhe@agrevolution.in'
file_name = 'Hingoli.csv'


msg = EmailMessage()
msg['Subject'] = 'Hingoli || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Kiran G Paikrao,\nPlease find below attachment of UTR of Hingoli.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Washim

Washim_NEFT = NEFT_Data.query('Name.str.startswith("Wash")', engine='python')
df1 = Washim_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Hingoli_NEFT = FE_Data.query('Name.str.startswith("Wash")', engine='python')
df2 = Washim_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Washim_Raw = pd.concat(df3)
Raw_Data = Washim_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'suraj.nimje@agrevolution.in'
cc = 'pramod.bachhao@agrevolution.in'
file_name = 'Washim.csv'


msg = EmailMessage()
msg['Subject'] = 'Washim || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Suraj Nimje,\nPlease find below attachment of UTR of Washim.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Vadodara

Vadodara_NEFT = NEFT_Data.query('Name.str.startswith("Vado")', engine='python')
df1 = Vadodara_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Vadodara_NEFT = FE_Data.query('Name == "Vado"')
df2 = Vadodara_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Vadodara_Raw = pd.concat(df3)
Raw_Data = Vadodara_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'patel.pratikkumar@agrevolution.in'
cc = 'vishal.joshi@agrevolution.in'
file_name = 'Vadodara.csv'


msg = EmailMessage()
msg['Subject'] = 'Vadodara || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Pratik Patel,\nPlease find below attachment of UTR of Vadodara.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Jalgaon

Jalgaon_NEFT = NEFT_Data.query('Name.str.startswith("Jalg")', engine='python')
df1 = Jalgaon_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Jalgaon_NEFT = FE_Data.query('Name.str.startswith("Jalg")', engine='python')
df2 = Jalgaon_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Jalgaon_Raw = pd.concat(df3)
Raw_Data = Jalgaon_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'sagar.kharchane@agrevolution.in'
cc = 'sahilv.gadhe@agrevolution.in'
file_name = 'Jalgaon.csv'


msg = EmailMessage()
msg['Subject'] = 'Jalgaon || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Kharchane Sagar Govind,\nPlease find below attachment of UTR of Jalgaon.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Ahmednagar

Ahmednagar_NEFT = NEFT_Data.query('Name.str.startswith("Ahmedn")', engine='python')
df1 = Ahmednagar_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Ahmednagar_NEFT = FE_Data.query('Name.str.startswith("Ahmedn")', engine='python')
df2 = Ahmednagar_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Ahmednagar_Raw = pd.concat(df3)
Raw_Data = Ahmednagar_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'dashrathV.pathare@agrevolution.in'
cc = 'ranjan.gudmeti@agrevolution.in'
file_name = 'Ahmednagar.csv'


msg = EmailMessage()
msg['Subject'] = 'Ahmednagar || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Dashrath V Pathare,\nPlease find below attachment of UTR of Ahmednagar.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Aurangabad

Aurangabad_NEFT = NEFT_Data.query('Name.str.startswith("Aura")', engine='python')
df1 = Aurangabad_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Aurangabad_NEFT = FE_Data.query('Name.str.startswith("Aura")', engine='python')
df2 = Aurangabad_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Aurangabad_Raw = pd.concat(df3)
Raw_Data = Aurangabad_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'shaikh.athar@agrevolution.in'
cc = 'sahilv.gadhe@agrevolution.in'
file_name = 'Aurangabad.csv'


msg = EmailMessage()
msg['Subject'] = 'Aurangabad || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Athar Shaikh,\nPlease find below attachment of UTR of Aurangabad.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Kolhapur

Kolhapur_NEFT = NEFT_Data.query('Name.str.startswith("Kolh")', engine='python')
df1 = Kolhapur_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Kolhapur_NEFT = FE_Data.query('Name.str.startswith("Kolh")', engine='python')
df2 = Kolhapur_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Kolhapur_Raw = pd.concat(df3)
Raw_Data = Kolhapur_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'raju.dalavi@agrevolution.in'
cc = 'sandeep.pawar@agrevolution.in'
file_name = 'Kolhapur.csv'


msg = EmailMessage()
msg['Subject'] = 'Kolhapur || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Raju Shamrav Dalavi,\nPlease find below attachment of UTR of Kolhapur.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Jalna

Jalna_NEFT = NEFT_Data.query('Name.str.startswith("Jaln")', engine='python')
df1 = Jalna_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Jalna_NEFT = FE_Data.query('Name.str.startswith("Jaln")', engine='python')
df2 = Jalna_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Jalna_Raw = pd.concat(df3)
Raw_Data = Jalna_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'shaikh.umar@agrevolution.in'
cc = 'sahilv.gadhe@agrevolution.in'
file_name = 'Jalna.csv'


msg = EmailMessage()
msg['Subject'] = 'Jalna || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Shaikh Umar,\nPlease find below attachment of UTR of Jalna.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Ujjain
Ujjain_NEFT = NEFT_Data.query('Name.str.startswith("Ujja")', engine='python')
df1 = Ujjain_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Ujjain_NEFT = FE_Data.query('Name.str.startswith("Ujja")', engine='python')
df2 = Ujjain_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Ujjain_Raw = pd.concat(df3)
Raw_Data = Ujjain_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'aditya.kaushik@agrevolution.in'
cc = 'sunil.mishra2@agrevolution.in'
file_name = 'Ujjain.csv'


msg = EmailMessage()
msg['Subject'] = 'Ujjain || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Aditya Kaushik,\nPlease find below attachment of UTR of Ujjain.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Jabalpur
Jabalpur_NEFT = NEFT_Data.query('Name.str.startswith("Jaba")', engine='python')
df1 = Jabalpur_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Jabalpur_NEFT = FE_Data.query('Name.str.startswith("Jaba")', engine='python')
df2 = Jabalpur_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Jabalpur_Raw = pd.concat(df3)
Raw_Data = Jabalpur_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'satyanarayan.sharma@agrevolution.in'
cc = 'sunil.mishra2@agrevolution.in'
file_name = 'Jabalpur.csv'


msg = EmailMessage()
msg['Subject'] = 'Jabalpur || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Satyanarayan Sharma,\nPlease find below attachment of UTR of Jabalpur.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Bhopal
Bhopal_NEFT = NEFT_Data.query('Name.str.startswith("Bhop")', engine='python')
df1 = Bhopal_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Bhopal_NEFT = FE_Data.query('Name.str.startswith("Bhop")', engine='python')
df2 = Bhopal_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Bhopal_Raw = pd.concat(df3)
Raw_Data = Bhopal_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'kapil.jain@agrevolution.in'
cc = 'sunil.mishra2@agrevolution.in'
file_name = 'Bhopal.csv'


msg = EmailMessage()
msg['Subject'] = 'Bhopal || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Kapil Jain,\nPlease find below attachment of UTR of Bhopal.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Khargone
Khargone_NEFT = NEFT_Data.query('Name.str.startswith("Khar")', engine='python')
df1 = Khargone_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Khargone_NEFT = FE_Data.query('Name.str.startswith("Khar")', engine='python')
df2 = Khargone_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Khargone_Raw = pd.concat(df3)
Raw_Data = Khargone_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'surendra.tiwari@agrevolution.in'
cc = 'sunil.mishra2@agrevolution.in'
file_name = 'Khargone.csv'


msg = EmailMessage()
msg['Subject'] = 'Khargone || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Surendra Tiwari,\nPlease find below attachment of UTR of Khargone.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Hoshangabd
Hoshangabd_NEFT = NEFT_Data.query('Name.str.startswith("Hosh")', engine='python')
df1 = Hoshangabd_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Hoshangabd_NEFT = FE_Data.query('Name.str.startswith("Hosh")', engine='python')
df2 = Hoshangabd_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Hoshangabd_Raw = pd.concat(df3)
Raw_Data = Hoshangabd_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'prashant.sapkale@agrevolution.in'
cc = 'sunil.mishra2@agrevolution.in'
file_name = 'Hoshangabd.csv'


msg = EmailMessage()
msg['Subject'] = 'Hoshangabd || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Prashant Sapkale,\nPlease find below attachment of UTR of Hoshangabd.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)

# %%
#Khandwa
Khandwa_NEFT = NEFT_Data.query('Name.str.startswith("Khan")', engine='python')
df1 = Khandwa_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
Khandwa_NEFT = FE_Data.query('Name.str.startswith("Khan")', engine='python')
df2 = Khandwa_NEFT[['Name','Transaction Date','Transaction Description','Transaction Amount','Debit','Reference No.','Value Date']]
df3 = [df1,df2]
Khandwa_Raw = pd.concat(df3)
Raw_Data = Khandwa_Raw.to_csv()

password = "hixt yzin loha eots"
sender = 'chaitanya.kumar@agrevolution.in'
#receiver = 'aityadav295@gmail.com'
#cc = "ak476697007@gmail.com"
receiver = 'suraj.chauhan@agrevolution.in'
cc = 'sunil.mishra2@agrevolution.in'
file_name = 'Khandwa.csv'


msg = EmailMessage()
msg['Subject'] = 'Khandwa || UTR'
msg['From'] = sender
msg['To'] = receiver
msg['cc'] = cc
msg.set_content('Hi Suraj Singh Chauhan,\nPlease find below attachment of UTR of Khandwa.\n\n\n\nRegards\nChaitanya')

msg.add_attachment(Raw_Data, subtype = 'octet-stream', filename=file_name)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
  smtp.login(sender, password)
  smtp.send_message(msg)
